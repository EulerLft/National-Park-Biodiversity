# %% [markdown]
# ## Introduction
#
# For this project we will interpret data from the National Parks Service about endangered species in different parks.
# We will perform data analysis on the conservation status of species and investigate if there are any patterns or themes to the types of species that become endangered.
# We will perform data clean, carry out analysis and develop visualizations as well as pose questions and seek answers to these questions in meaningful ways.
# After the analysis.

# %% [markdown]
# #### Import data
#
# Import data from both csv's and analyze them separate to ensure these are clean.

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 

# Import csv's into separate data frames 
df_observations = pd.read_csv('observations.csv')
df_species_info = pd.read_csv('species_info.csv')

# %% [markdown]
# ## Species Info Data
#
# we will look at the Species Info first, and make sure this dataset is clean - e.g, handling missing values, handling duplicates, etc.

# %%
df_species_info.head()
# Out:
#   category                scientific_name  \
# 0   Mammal  Clethrionomys gapperi gapperi
# 1   Mammal                      Bos bison
# 2   Mammal                     Bos taurus
# 3   Mammal                     Ovis aries
# 4   Mammal                 Cervus elaphus
#
#                                         common_names conservation_status
# 0                           Gapper's Red-Backed Vole                 NaN
# 1                              American Bison, Bison                 NaN
# 2  Aurochs, Aurochs, Domestic Cattle (Feral), Dom...                 NaN
# 3  Domestic Sheep, Mouflon, Red Sheep, Sheep (Feral)                 NaN
# 4                                      Wapiti Or Elk                 NaN

# %%
print(f'rows: {df_species_info.shape[0]}')
print(f'columns: {df_species_info.shape[1]}')
print(f"\nCategories: {df_species_info['category'].unique()}")
print(f"\nNumber of species (Scientific Names): {df_species_info['scientific_name'].nunique()}")
print(f"\nNumber of species (common Names): {df_species_info['scientific_name'].nunique()}")
print(f"\nConservation Statuses: {df_species_info['conservation_status'].unique()}")

print('')
df_species_info.count()

maxRows = df_species_info['scientific_name'].count()
print('Missing Rows: ')
print(maxRows - df_species_info.count())
print('')
# Out:
# rows: 5824
# columns: 4
#
# Categories: ['Mammal' 'Bird' 'Reptile' 'Amphibian' 'Fish' 'Vascular Plant'
#  'Nonvascular Plant']
#
# Number of species (Scientific Names): 5541
#
# Number of species (common Names): 5541
#
# Conservation Statuses: [nan 'Species of Concern' 'Endangered' 'Threatened' 'In Recovery']
#
# Missing Rows:
# category                  0
# scientific_name           0
# common_names              0
# conservation_status    5633
# dtype: int64

# %%
df_species_info.count()
# Out:
# category               5824
# scientific_name        5824
# common_names           5824
# conservation_status     191
# dtype: int64

# %% [markdown]
# ### Data Characteristics:
#
# "species_info" has 5824 records with 4 columns: (<b> category </b>, <b> scientific_name </b>, <b> common_name </b>, <b> conservation_status </b>). \
# These columns include the following unique values:
# -    Category: [Mammal, Bird, Repitle, Amphibian, Fish, Vascular Plant, Nonvascular Plant]
# -    scientific names: 5,541
# -    common names: 5,541
# -    Conservation Statuses : [NaN, Species of Concern, Endangered, Threatened, In Recovery]
#
# We carry out analysis to look for "missing" values in our data. We do this by counting the number of values in each of the columns.
#
# | Column | Value / Count |
# | ---: | ---: |
# | **category** | 5824 |
# | **scientific_name** | 5824 |
# | **common_name** | 5824 |
# | **conservation_status** | 191 |
#
# The conservation status is missing >95% values - we will need to change NaN into something more descriptive. (e.g., Not Evaluated, Data Deficient, etc.) \
# (5,633 rows have no conservation status). We could choose to drop this column, but we may be able to still extract information from it, so we will apply the change first.
#
# Next we look at "duplicate" rows. There are 283 duplicates with the same scientific name - these could having duplicates of category, common name or conservation status.
# - 5,824 total records
# - 5,541 unique scientific names
# - 283 duplicate

# %%
duplicates = df_species_info[df_species_info.duplicated(subset=['scientific_name'])].sort_values(by='scientific_name')
duplicates.count()
# Out:
# category               283
# scientific_name        283
# common_names           283
# conservation_status     13
# dtype: int64

# %%
duplicates_2 = df_species_info[df_species_info.duplicated(subset=['scientific_name', 'conservation_status'])]
duplicates_2.count()
# Out:
# category               281
# scientific_name        281
# common_names           281
# conservation_status     11
# dtype: int64

# %% [markdown]
# #### Dealing With Duplicate Values
#
# Above we see that 283 records have duplicated scientific names. Next, we need to think if these are due to duplicate category, common name, or status. \
# We see that 281 records have the same conservation status for every scientific name - two records w/ duplicate scientific name have different conservation status.
#
# #### Filling NaN
# First, we will fill the NaN values in conservation status with "Not Evaluated". We choose to state "Not Evaluated" as we might be able to find species not observed in multiple \
# parks and give some predictor to the conservation status of species based on the number of observations across the board. Assuming these are safe species could be dangerous.

# %%
species_test = df_species_info.copy()
species_test = species_test.drop_duplicates(subset=['scientific_name', 'conservation_status']).reset_index()
species_test = species_test.drop(columns=['index'])
species_test['conservation_status'] = species_test['conservation_status'].fillna('Data Deficient')
species_test
# Out:
#             category                scientific_name  \
# 0             Mammal  Clethrionomys gapperi gapperi
# 1             Mammal                      Bos bison
# 2             Mammal                     Bos taurus
# 3             Mammal                     Ovis aries
# 4             Mammal                 Cervus elaphus
# ...              ...                            ...
# 5538  Vascular Plant               Solanum parishii
# 5539  Vascular Plant                  Solanum xanti
# 5540  Vascular Plant         Parthenocissus vitacea
# 5541  Vascular Plant              Vitis californica
# 5542  Vascular Plant            Tribulus terrestris
#
#                                            common_names conservation_status
# 0                              Gapper's Red-Backed Vole      Data Deficient
# 1                                 American Bison, Bison      Data Deficient
# 2     Aurochs, Aurochs, Domestic Cattle (Feral), Dom...      Data Deficient
# ...

# %% [markdown]
# #### Order Categorical Data
#
# We will order the conservation_status to ensure that we keep the more relevant of the two statuses. For example, if a species is recorded as both "engangered" and "data deficient" we want to keep the "endangered" status, since this is the more severe conservation status.

# %%
custom_order = ['Endangered', 'Threatened', 'Species of Concern', 'In Recovery', 'Data Deficient']

from pandas.api.types import CategoricalDtype 

cat_type = CategoricalDtype(categories=custom_order, ordered=True)

species_test['conservation_status'] = species_test['conservation_status'].astype(cat_type)

species_test = species_test.sort_values('conservation_status')
species_test
# Out:
#             category                     scientific_name  \
# 4388       Amphibian                        Rana sierrae
# 34            Mammal                   Myotis grisescens
# 276             Bird                 Vermivora bachmanii
# 343             Bird                   Picoides borealis
# 540             Fish                Etheostoma percnurum
# ...              ...                                 ...
# 1898  Vascular Plant  Oenothera fruticosa ssp. fruticosa
# 1897  Vascular Plant                   Oenothera biennis
# 1896  Vascular Plant               Ludwigia uruguayensis
# 1904  Vascular Plant            Nuphar lutea ssp. advena
# 5542  Vascular Plant                 Tribulus terrestris
#
#                                            common_names conservation_status
# 4388                   Sierra Nevada Yellow-Legged Frog          Endangered
# 34                                          Gray Myotis          Endangered
# ...

# %% [markdown]
# There are two duplicates (2 canis lupus and 2 oncorhynchus mykiss) with different conservation_status.
#
# By applying our ordering, we have the first entry of each as the most relevant conservation status that we'd want to consider: \
# ('Endangered' > 'Threatened' > 'Species of Concern' > 'In Recovery' > 'Data Deficient'

# %%
duplicated_data = species_test[species_test.duplicated(subset=['scientific_name'], keep=False)]
duplicated_data.sort_values(by='scientific_name')
# Out:
#      category      scientific_name     common_names conservation_status
# 8      Mammal          Canis lupus        Gray Wolf          Endangered
# 3018   Mammal          Canis lupus  Gray Wolf, Wolf         In Recovery
# 3247     Fish  Oncorhynchus mykiss    Rainbow Trout          Threatened
# 560      Fish  Oncorhynchus mykiss    Rainbow Trout      Data Deficient

# %%
species_test2 = species_test.drop_duplicates(subset=['scientific_name'], keep='first').reset_index()
species_test2
# Out:
#       index        category                     scientific_name  \
# 0      4388       Amphibian                        Rana sierrae
# 1        34          Mammal                   Myotis grisescens
# 2       276            Bird                 Vermivora bachmanii
# 3       343            Bird                   Picoides borealis
# 4       540            Fish                Etheostoma percnurum
# ...     ...             ...                                 ...
# 5536   1898  Vascular Plant  Oenothera fruticosa ssp. fruticosa
# 5537   1897  Vascular Plant                   Oenothera biennis
# 5538   1896  Vascular Plant               Ludwigia uruguayensis
# 5539   1904  Vascular Plant            Nuphar lutea ssp. advena
# 5540   5542  Vascular Plant                 Tribulus terrestris
#
#                                            common_names conservation_status
# 0                      Sierra Nevada Yellow-Legged Frog          Endangered
# ...

# %%
print(species_test2.loc[species_test2['scientific_name'] == 'Canis lupus'])
print('')
print(species_test2.loc[species_test2['scientific_name'] == 'Oncorhynchus mykiss'])
# Out:
#    index category scientific_name common_names conservation_status
# 7      8   Mammal     Canis lupus    Gray Wolf          Endangered
#
#     index category      scientific_name   common_names conservation_status
# 20   3247     Fish  Oncorhynchus mykiss  Rainbow Trout          Threatened

# %%
print('Duplicate by Category & Scientific Name: \n', species_test2.duplicated(subset=['scientific_name', 'category']).value_counts())
print('')
print('Duplicate by common name & Scientific Name: \n', species_test2.duplicated(subset=['scientific_name', 'common_names']).value_counts())
print('')
print('Duplicate by conservation status & Scientific Name: \n', species_test2.duplicated(subset=['scientific_name', 'conservation_status']).value_counts())
# Out:
# Duplicate by Category & Scientific Name:
#  False    5541
# dtype: int64
#
# Duplicate by common name & Scientific Name:
#  False    5541
# dtype: int64
#
# Duplicate by conservation status & Scientific Name:
#  False    5541
# dtype: int64

# %% [markdown]
# We can see now that the two species We've handled all the duplicates in species_info, and now have a clean dataset ready for analysis.

# %% [markdown]
# ## Caveat:
#
# Note that the species_info.csv table may produced by appending new status updates to a master file over several years. \
# e.g., Canis Lupus moved from "Engangered" to "In Recovery" due to a later data input some time later. \
# If we could have reason to believe the file is organized chronologically, then lowest entry on the list for a specific scientific name would be the most accurate. \
# (i.e. logging systems where new status updates are appended to the end of the file)
#
# However, biodiversity data may come from different sources - e.g., one entry reflects federal status while another reflects state-level status. \
# In these cases, taking the "latest" record may prioritize a less severe status just because it was the last one entered into the spreadsheet.\
# Since we are aiming for a clean dataset, the most robust path is to use the hierarchy of importance. \
# Therefore, For species with multiple records, we have retained the status representing the highest level of conservation concern.

# %% [markdown]
# ## Park Observation Data

# %%
df_observations.head()
# Out:
#             scientific_name                            park_name  observations
# 0        Vicia benghalensis  Great Smoky Mountains National Park            68
# 1            Neovison vison  Great Smoky Mountains National Park            77
# 2         Prunus subcordata               Yosemite National Park           138
# 3      Abutilon theophrasti                  Bryce National Park            84
# 4  Githopsis specularioides  Great Smoky Mountains National Park            85

# %%
print("Observations: ")

print(f"\nnumber of species: {df_observations['scientific_name'].nunique()}")
print(f"\nparks: {df_observations['park_name'].unique()}")

print('')
df_observations.count()
# Out:
# Observations:
#
# number of species: 5541
#
# parks: ['Great Smoky Mountains National Park' 'Yosemite National Park'
#  'Bryce National Park' 'Yellowstone National Park']
# scientific_name    23296
# park_name          23296
# observations       23296
# dtype: int64

# %%
duplicates = df_observations.duplicated(subset=['scientific_name', 'park_name'])
print(duplicates.value_counts())
# Out:
# False    22164
# True      1132
# dtype: int64

# %%
df_observations[['scientific_name', 'park_name']].groupby('park_name').count()
# Out:
#                                      scientific_name
# park_name
# Bryce National Park                             5824
# Great Smoky Mountains National Park             5824
# Yellowstone National Park                       5824
# Yosemite National Park                          5824

# %%
print('number of duplicate species per park: ', 5824 - 5541)
print('283 (duplicates) * 4 (parks) = ', 283 * 4)
print('(i.e. the number of duplicates per park match the total number of duplicates on the entire dataset)')
# Out:
# number of duplicate species per park:  283
# 283 (duplicates) * 4 (parks) =  1132
# (i.e. the number of duplicates per park match the total number of duplicates on the entire dataset)

# %% [markdown]
# #### Dealing with Duplicates
#
# Species were recorded multiple times for each park, therefore we need to add the number of observations by each species, to get the total observations. \
# The easiest way to do this is to break it up by different parks, which will make the JOIN with the species info very straight forward as the data will have the same number of rows.
# Keeping the four parks into separate dataframes will allow us to carry out analysis per park, and then bring it all together.

# %%
bryce_park_duplicates = bryce_park[bryce_park.duplicated(subset=['scientific_name'], keep=False)]
bryce_park_duplicates.sort_values(by='scientific_name')
# Out:
#            scientific_name            park_name  observations
# 4864   Agrostis capillaris  Bryce National Park           105
# 3993   Agrostis capillaris  Bryce National Park           103
# 8676     Agrostis gigantea  Bryce National Park           116
# 6824     Agrostis gigantea  Bryce National Park           104
# 3199    Agrostis mertensii  Bryce National Park            74
# ...                    ...                  ...           ...
# 20392        Vulpia myuros  Bryce National Park           111
# 17498     Vulpia octoflora  Bryce National Park            92
# 3575      Vulpia octoflora  Bryce National Park            90
# 13904         Zizia aptera  Bryce National Park           112
# 10913         Zizia aptera  Bryce National Park           105
#
# [557 rows x 3 columns]

# %%
smoky_mountain_park_duplicates = smoky_mountain_park[smoky_mountain_park.duplicated(subset=['scientific_name'])]
smoky_mountain_park_duplicates.sort_values(by='scientific_name')
# Out:
#             scientific_name                            park_name  observations
# 17428   Agrostis capillaris  Great Smoky Mountains National Park            97
# 11602     Agrostis gigantea  Great Smoky Mountains National Park            57
# 9721     Agrostis mertensii  Great Smoky Mountains National Park            87
# 12730       Agrostis scabra  Great Smoky Mountains National Park            48
# 16805  Agrostis stolonifera  Great Smoky Mountains National Park           106
# ...                     ...                                  ...           ...
# 19551      Vireo solitarius  Great Smoky Mountains National Park            97
# 15131      Vulpia bromoides  Great Smoky Mountains National Park            81
# 15058         Vulpia myuros  Great Smoky Mountains National Park            52
# 21158      Vulpia octoflora  Great Smoky Mountains National Park            17
# 11138          Zizia aptera  Great Smoky Mountains National Park            41
#
# [283 rows x 3 columns]

# %%
yosemite_park_duplicates = yosemite_park[yosemite_park.duplicated(subset=['scientific_name'])]
yosemite_park_duplicates.sort_values(by='scientific_name')
# Out:
#             scientific_name               park_name  observations
# 17735   Agrostis capillaris  Yosemite National Park           140
# 17535     Agrostis gigantea  Yosemite National Park           128
# 490      Agrostis mertensii  Yosemite National Park           128
# 18036       Agrostis scabra  Yosemite National Park           170
# 22613  Agrostis stolonifera  Yosemite National Park           156
# ...                     ...                     ...           ...
# 9412       Vireo solitarius  Yosemite National Park           140
# 15267      Vulpia bromoides  Yosemite National Park           166
# 7863          Vulpia myuros  Yosemite National Park           125
# 12802      Vulpia octoflora  Yosemite National Park           124
# 14300          Zizia aptera  Yosemite National Park           129
#
# [283 rows x 3 columns]

# %%
yellowstone_park_duplicates = yellowstone_park[yellowstone_park.duplicated(subset=['scientific_name'])]
yellowstone_park_duplicates.sort_values(by='scientific_name')
# Out:
#             scientific_name                  park_name  observations
# 10379   Agrostis capillaris  Yellowstone National Park           267
# 483       Agrostis gigantea  Yellowstone National Park           235
# 6169     Agrostis mertensii  Yellowstone National Park           251
# 8147        Agrostis scabra  Yellowstone National Park           253
# 16663  Agrostis stolonifera  Yellowstone National Park           288
# ...                     ...                        ...           ...
# 13750      Vireo solitarius  Yellowstone National Park           233
# 20747      Vulpia bromoides  Yellowstone National Park           247
# 17615         Vulpia myuros  Yellowstone National Park           248
# 18936      Vulpia octoflora  Yellowstone National Park           245
# 17162          Zizia aptera  Yellowstone National Park           269
#
# [283 rows x 3 columns]

# %%
observation_data = df_observations.groupby(['scientific_name', 'park_name'])['observations'].sum().reset_index()
observation_data
# Out:
#                            scientific_name  \
# 0                            Abies bifolia
# 1                            Abies bifolia
# 2                            Abies bifolia
# 3                            Abies bifolia
# 4                           Abies concolor
# ...                                    ...
# 22159                 Zygodon viridissimus
# 22160  Zygodon viridissimus var. rupestris
# 22161  Zygodon viridissimus var. rupestris
# 22162  Zygodon viridissimus var. rupestris
# 22163  Zygodon viridissimus var. rupestris
#
#                                  park_name  observations
# 0                      Bryce National Park           109
# 1      Great Smoky Mountains National Park            72
# 2                Yellowstone National Park           215
# 3                   Yosemite National Park           136
# 4                      Bryce National Park            83
# ...                                    ...           ...
# ...

# %%
species_test2 = species_test2.drop(columns=['index']) 
species_test2
# Out:
#             category                     scientific_name  \
# 0          Amphibian                        Rana sierrae
# 1             Mammal                   Myotis grisescens
# 2               Bird                 Vermivora bachmanii
# 3               Bird                   Picoides borealis
# 4               Fish                Etheostoma percnurum
# ...              ...                                 ...
# 5536  Vascular Plant  Oenothera fruticosa ssp. fruticosa
# 5537  Vascular Plant                   Oenothera biennis
# 5538  Vascular Plant               Ludwigia uruguayensis
# 5539  Vascular Plant            Nuphar lutea ssp. advena
# 5540  Vascular Plant                 Tribulus terrestris
#
#                                            common_names conservation_status
# 0                      Sierra Nevada Yellow-Legged Frog          Endangered
# 1                                           Gray Myotis          Endangered
# ...

# %%
master_df = pd.merge(observation_data, species_test2, how='left')

master_df.isnull().sum()
# Out:
# scientific_name        0
# park_name              0
# observations           0
# category               0
# common_names           0
# conservation_status    0
# dtype: int64

# %%
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22164 entries, 0 to 22163
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   scientific_name      22164 non-null  object
#  1   park_name            22164 non-null  object
#  2   observations         22164 non-null  int64
#  3   category             22164 non-null  object
#  4   common_names         22164 non-null  object
#  5   conservation_status  22164 non-null  category
# dtypes: category(1), int64(1), object(4)
# memory usage: 1.0+ MB

# %%
pd.merge()
